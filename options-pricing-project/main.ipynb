# %% [markdown]
# # Options Pricing Calculator
#
# This notebook launches the complete project workflow.
#
# Edit the settings near the top of `main.py`, then run the next cell.

# %%
import importlib
import main

importlib.reload(main)
project = main.main()
# Out:
# ...
# OPTIONS PRICING CALCULATOR
# ...
# {
#   "spot": 100.0,
#   "strike": 100.0,
#   "time_to_expiry": 0.5,
#   "risk_free_rate": 0.05,
#   "volatility": 0.2,
#   "dividend_yield": 0.01,
#   "option_type": "call"
# }
#
# MODEL PRICE COMPARISON
#                  method    price  standard_error  confidence_low  confidence_high
#    Black-Scholes-Merton 6.594025             NaN             NaN              NaN
# CRR Binomial — European 6.591689             NaN             NaN              NaN
#             Monte Carlo 6.606874        0.008305        6.590596         6.623152
#
# BLACK-SCHOLES PRICES
# Call: 6.594025
# Put:  4.623769
#
# PUT-CALL PARITY
# Residual: -0.000000000000
#
# RECOVERED IMPLIED VOLATILITY
# 20.000000%
#
# CALL GREEKS
# delta: 0.581085
# gamma: 0.027444
# vega_per_1pct: 0.274443
# theta_per_year: -7.483497
# theta_per_day: -0.020503
# rho_per_1pct: 0.257573
#
# AMERICAN PUT
# european_price: 4.621433
# american_price: 4.811397
# early_exercise_premium: 0.189964
#
# ...

# %% [markdown]
# ## Available results
#
# ```python
# project["summary"]
# project["comparison"]
# project["surface"]
# project["greek_profile"]
# ```
#
# The same outputs are saved in the `outputs` folder.
